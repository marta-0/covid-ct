# %%
from covid.models import *
from covid.gradcam import GradCAM, show_gradcam
from covid.utils import load_efficientnet

# %% [markdown]
# Images paths - chosen specifically to be the same image, but on different stages of preprocessing:

# %%
PATHS_COV = ['Data/CT-COV19/Val/COV/30/FILE0016.jpg', 'Data/CT-COV-Contour/Val/COV/863.png', 'Data/CT-COV-Crop/Val/COV/863.png', 'Data/CT-COV-Lungs/Val/COV/887.png', 'Data/CT-COV-Lungs-Crop/Val/COV/887.png']
PATHS_NORM = ['Data/CT-COV19/Val/Normal/1/neg_2573.png', 'Data/CT-COV-Contour/Val/Normal/921.png', 'Data/CT-COV-Crop/Val/Normal/921.png', 'Data/CT-COV-Lungs/Val/Normal/1036.png', 'Data/CT-COV-Lungs-Crop/Val/Normal/1036.png']
PATHS_OTHER = ['Data/CT-COV19/Val/OtherPneumonia/pneu_55.png', 'Data/CT-COV-Contour/Val/OtherPneumonia/1314.png','Data/CT-COV-Crop/Val/OtherPneumonia/1314.png', 'Data/CT-COV-Lungs/Val/OtherPneumonia/1310.png', 'Data/CT-COV-Lungs-Crop/Val/OtherPneumonia/1310.png']

# %% [markdown]
# ## LargeT

# %% [markdown]
# GradCAM analysis for the best model according to the f1 score achieved on the validation set - LargeT.

# %% [markdown]
# ### Class COV - different model checkpoints

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 1}
model = get_model_larget(**img_params)
model.load_weights('best-models/' + 'larget' + '-weights/' + 'first' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params, 0)

# %%
model = get_model_larget(**img_params)
model.load_weights('best-models/' + 'larget' + '-weights/' + 'first-classw' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params, 0)

# %%
model = get_model_larget(**img_params)
model.load_weights('best-models/' + 'larget' + '-weights/' + 'first-dataaug' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params, 0)

# %%
model = get_model_larget(**img_params)
model.load_weights('best-models/' + 'larget' + '-weights/' + 'first-classw-dataaug' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params, 0)

# %% [markdown]
# ### Class COV - different stages of image preprocessing

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 1}
model = get_model_larget(**img_params)
model.load_weights('best-models/' + 'larget' + '-weights/' + 'nobackg' + '.ckpt')

# %%
show_gradcam(PATHS_COV[1], model, img_params, 0)

# %%
img_params = {'img_width': 512,
              'img_height': 328,
              'num_channels': 1}
model = get_model_larget(**img_params)
model.load_weights('best-models/' + 'larget' + '-weights/' + 'crop' + '.ckpt')

# %%
show_gradcam(PATHS_COV[2], model, img_params, 0)

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 1}
model = get_model_larget(**img_params)
model.load_weights('best-models/' + 'larget' + '-weights/' + 'lungs-nocrop' + '.ckpt')

# %%
show_gradcam(PATHS_COV[3], model, img_params, 0)

# %%
img_params = {'img_width': 330,
              'img_height': 256,
              'num_channels': 1}
model = get_model_larget(**img_params)
model.load_weights('best-models/' + 'larget' + '-weights/' + 'lungs' + '.ckpt')

# %%
show_gradcam(PATHS_COV[4], model, img_params, 0)

# %% [markdown]
# ### Different classes

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 1}
model = get_model_larget(**img_params)
model.load_weights('best-models/' + 'larget' + '-weights/' + 'first' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params)
show_gradcam(PATHS_NORM[0], model, img_params)
show_gradcam(PATHS_OTHER[0], model, img_params)

# %%
show_gradcam(PATHS_COV[0], model, img_params, 0)
show_gradcam(PATHS_COV[0], model, img_params, 1)
show_gradcam(PATHS_COV[0], model, img_params, 2)

# %%
show_gradcam(PATHS_NORM[0], model, img_params, 0)
show_gradcam(PATHS_NORM[0], model, img_params, 1)
show_gradcam(PATHS_NORM[0], model, img_params, 2)

# %%
show_gradcam(PATHS_OTHER[0], model, img_params, 0)
show_gradcam(PATHS_OTHER[0], model, img_params, 1)
show_gradcam(PATHS_OTHER[0], model, img_params, 2)

# %% [markdown]
# ## EfficientNet B3 - ImageNet

# %% [markdown]
# ### Class COV - different model checkpoints

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 3}

# %%
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'first' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params)

# %%
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'first-classw' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params)

# %%
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'first-dataaug' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params)

# %%
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'first-classw-dataaug' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params)

# %% [markdown]
# ### Class COV - different stages of image preprocessing

# %%
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'nobackg' + '.ckpt')

# %%
show_gradcam(PATHS_COV[1], model, img_params, 0)

# %%
img_params = {'img_width': 512,
              'img_height': 328,
              'num_channels': 3}
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'crop' + '.ckpt')

# %%
show_gradcam(PATHS_COV[2], model, img_params, 0)

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 3}
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'lungs-nocrop' + '.ckpt')

# %%
show_gradcam(PATHS_COV[3], model, img_params, 0)

# %%
img_params = {'img_width': 330,
              'img_height': 256,
              'num_channels': 3}
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'lungs' + '.ckpt')

# %%
show_gradcam(PATHS_COV[4], model, img_params, 0)

# %% [markdown]
# ### Different classes

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 3}
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'first' + '.ckpt')
show_gradcam(PATHS_COV[0], model, img_params, 0)
show_gradcam(PATHS_NORM[0], model, img_params, 1)
show_gradcam(PATHS_OTHER[0], model, img_params, 2)

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 3}
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'nobackg' + '.ckpt')
show_gradcam(PATHS_COV[1], model, img_params, 0)
show_gradcam(PATHS_NORM[1], model, img_params, 1)
show_gradcam(PATHS_OTHER[1], model, img_params, 2)

# %%
img_params = {'img_width': 512,
              'img_height': 328,
              'num_channels': 3}
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'crop' + '.ckpt')
show_gradcam(PATHS_COV[2], model, img_params, 0)
show_gradcam(PATHS_NORM[2], model, img_params, 1)
show_gradcam(PATHS_OTHER[2], model, img_params, 2)

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 3}
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'lungs-nocrop' + '.ckpt')
show_gradcam(PATHS_COV[3], model, img_params, 0)
show_gradcam(PATHS_NORM[3], model, img_params, 1)
show_gradcam(PATHS_OTHER[3], model, img_params, 2)

# %%
img_params = {'img_width': 330,
              'img_height': 256,
              'num_channels': 3}
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'lungs' + '.ckpt')
show_gradcam(PATHS_COV[4], model, img_params, 0)
show_gradcam(PATHS_NORM[4], model, img_params, 1)
show_gradcam(PATHS_OTHER[4], model, img_params, 2)

# %% [markdown]
# ## EfficientNet B3 - weights None

# %% [markdown]
# ### Class COV - different model checkpoints

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 3}

# %%
model = load_efficientnet(**img_params)
model.load_weights('best-models/' + 'efficientnetb3' + '-weights/' + 'first' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params)

# %%
model = load_efficientnet(**img_params)
model.load_weights('best-models/' + 'efficientnetb3' + '-weights/' + 'first-classw' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params)

# %%
model = load_efficientnet(if_dataaug=True, data_augmentation=dataaug_layer(0.1, -0.2, 0.1, **img_params), **img_params)
model.load_weights('best-models/' + 'efficientnetb3' + '-weights/' + 'first-dataaug' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params)

# %%
model = load_efficientnet(if_dataaug=True, data_augmentation=dataaug_layer(0.1, -0.2, 0.1, **img_params), **img_params)
model.load_weights('best-models/' + 'efficientnetb3' + '-weights/' + 'first-classw-dataaug' + '.ckpt')

# %%
show_gradcam(PATHS_COV[0], model, img_params)

# %% [markdown]
# ### Class COV - different stages of image preprocessing

# %%
model = load_efficientnet(**img_params)
model.load_weights('best-models/' + 'efficientnetb3' + '-weights/' + 'nobackg' + '.ckpt')

# %%
show_gradcam(PATHS_COV[1], model, img_params)

# %%
img_params = {'img_width': 512,
              'img_height': 328,
              'num_channels': 3}
model = load_efficientnet(**img_params)
model.load_weights('best-models/' + 'efficientnetb3' + '-weights/' + 'crop' + '.ckpt')

# %%
show_gradcam(PATHS_COV[2], model, img_params)

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 3}
model = load_efficientnet(**img_params)
model.load_weights('best-models/' + 'efficientnetb3' + '-weights/' + 'lungs-nocrop' + '.ckpt')

# %%
show_gradcam(PATHS_COV[3], model, img_params)

# %%
img_params = {'img_width': 330,
              'img_height': 256,
              'num_channels': 3}
model = load_efficientnet(**img_params)
model.load_weights('best-models/' + 'efficientnetb3' + '-weights/' + 'lungs' + '.ckpt')

# %%
show_gradcam(PATHS_COV[4], model, img_params)

# %% [markdown]
# ## EfficientNets B3 - comparison

# %%
img_params = {'img_width': 330,
              'img_height': 256,
              'num_channels': 3}

PATH_COV = ['Data/CT-COV-Lungs-Crop/Val/COV/0.png']
PATH_NORM = ['Data/CT-COV-Lungs-Crop/Val/Normal/908.png']
PATH_OTHER = ['Data/CT-COV-Lungs-Crop/Val/OtherPneumonia/1296.png']

# %% [markdown]
# #### Weights None

# %%
model = load_efficientnet(**img_params)
model.load_weights('best-models/' + 'efficientnetb3' + '-weights/' + 'lungs' + '.ckpt')

show_gradcam(PATH_COV[0], model, img_params, 0)
show_gradcam(PATH_NORM[0], model, img_params, 1)
show_gradcam(PATH_OTHER[0], model, img_params, 2)

# %% [markdown]
# #### Weights ImageNet

# %%
model = get_efficientnet_b3(**img_params)
model.load_weights('best-models/' + 'efficientnetb3-imagenet' + '-weights/' + 'lungs' + '.ckpt')

show_gradcam(PATH_COV[0], model, img_params, 0)
show_gradcam(PATH_NORM[0], model, img_params, 1)
show_gradcam(PATH_OTHER[0], model, img_params, 2)

# %% [markdown]
# # Best models

# %% [markdown]
# Best model checkpoint of each model architecture.

# %% [markdown]
# ## Simple

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 1}
model = get_model_simple(**img_params)
model.load_weights('best-models/' + 'simple' + '-weights/' + 'first-classw-dataaug' + '.ckpt')

show_gradcam(PATHS_COV[0], model, img_params)

# %% [markdown]
# ## Tiny

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 1}
model = get_model_tiny(**img_params)
model.load_weights('best-models/' + 'tiny' + '-weights/' + 'first' + '.ckpt')

show_gradcam(PATHS_COV[0], model, img_params)

# %% [markdown]
# ## Small

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 1}
model = get_model_small(**img_params)
model.load_weights('best-models/' + 'small' + '-weights/' + 'first' + '.ckpt')

show_gradcam(PATHS_COV[0], model, img_params)

# %% [markdown]
# ## LargeW

# %%
img_params = {'img_width': 512,
              'img_height': 512,
              'num_channels': 1}
model = get_model_largew(**img_params)
model.load_weights('best-models/' + 'largew' + '-weights/' + 'first-classw' + '.ckpt')

show_gradcam(PATHS_COV[0], model, img_params)
